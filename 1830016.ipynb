# %%
import numpy as np
import matplotlib.pyplot as plt
min_val = -100 
max_val = 100
milxdos = np.random.randint(min_val,max_val,(1000,2))
print(milxdos)
plt.scatter(milxdos[:,0],milxdos[:,1])
plt.show()
# Out:
# [[ 90  30]
#  [ -8  -4]
#  [-22  99]
#  ...
#  [ 70  51]
#  [ 46   7]
#  [  4 -44]]
